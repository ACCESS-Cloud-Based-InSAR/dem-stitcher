# %%
from dem_stitcher.stitcher import download_dem 
import rasterio
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Bay Area
bounds: list = [-121.5, 34.95, -120.2, 36.25]
dem_name: str = 'glo_30'
save_raw_tiles: bool = False
force_agi_read: bool = True
test_dir: str = '.'

# %%
# Parameters
dem_name = "glo_30"
out_dir = "/Users/cmarshak/bekaert-team/dem-stitcher/tests/out"

# %% [markdown]
# # Check Download

# %%
# %%time

out_path = download_dem(bounds, 
                        dem_name, 
                        f'{test_dir}/{dem_name}_test',
                        save_raw_tiles=save_raw_tiles,
                        # More than 5 workers can cause timeout errors.
                        max_workers=5,
                        force_agi_read_for_geoid=force_agi_read)
out_path
# Out:
# Downloading glo_30 tiles:   0%|          | 0/6 [00:00<?, ?it/s]
# Downloading glo_30 tiles:  17%|█▋        | 1/6 [00:01<00:05,  1.15s/it]
# Downloading glo_30 tiles:  33%|███▎      | 2/6 [00:21<00:49, 12.45s/it]
# Downloading glo_30 tiles:  67%|██████▋   | 4/6 [01:07<00:38, 19.05s/it]
# Downloading glo_30 tiles:  83%|████████▎ | 5/6 [01:18<00:16, 16.51s/it]
# Downloading glo_30 tiles: 100%|██████████| 6/6 [01:18<00:00, 13.05s/it]
# CPU times: user 15.7 s, sys: 2.72 s, total: 18.5 s
# Wall time: 1min 24s
# PosixPath('glo_30_test/glo_30.dem.wgs84')

# %%
with rasterio.open(out_path) as ds:
    X_0 = ds.read(1)
    p_0 = ds.profile

# %%
fig, ax = plt.subplots()
im = ax.imshow(X_0, vmin=0)
fig.colorbar(im, label='Ellipsoidal Height (m)')

# %%
data_dir = out_path.parents[0]
[file.unlink() for file in data_dir.glob('*')]
data_dir.rmdir()
