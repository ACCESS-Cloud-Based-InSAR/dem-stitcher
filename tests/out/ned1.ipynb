# %%
from dem_stitcher.stitcher import download_dem 
import rasterio
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Bay Area
bounds: list = [-121.5, 34.95, -120.2, 36.25]
dem_name: str = 'glo_30'
save_raw_tiles: bool = False
force_agi_read: bool = True
test_dir: str = '.'

# %%
# Parameters
dem_name = "ned1"
test_dir = "/Users/cmarshak/bekaert-team/dem-stitcher/tests"

# %% [markdown]
# # Check Download

# %%
# %%time

out_path = download_dem(bounds, 
                        dem_name, 
                        f'{test_dir}/{dem_name}_test',
                        save_raw_tiles=save_raw_tiles,
                        # More than 5 workers can cause timeout errors.
                        max_workers=5,
                        force_agi_read_for_geoid=force_agi_read)
out_path
# Out:
# Downloading ned1 tiles:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading ned1 tiles:  20%|██        | 1/5 [00:06<00:24,  6.21s/it]
# Downloading ned1 tiles:  40%|████      | 2/5 [00:16<00:26,  8.84s/it]
# Downloading ned1 tiles: 100%|██████████| 5/5 [00:17<00:00,  2.57s/it]
# Downloading ned1 tiles: 100%|██████████| 5/5 [00:17<00:00,  3.43s/it]
# CPU times: user 9.15 s, sys: 2.89 s, total: 12 s
# Wall time: 25.6 s
# PosixPath('/Users/cmarshak/bekaert-team/dem-stitcher/tests/ned1_test/ned1.dem.wgs84')

# %%
with rasterio.open(out_path) as ds:
    X_0 = ds.read(1)
    p_0 = ds.profile

# %%
fig, ax = plt.subplots()
im = ax.imshow(X_0, vmin=0)
fig.colorbar(im, label='Ellipsoidal Height (m)')

# %% [markdown]
# Remove all data files.

# %%
data_dir = out_path.parents[0]
[file.unlink() for file in data_dir.glob('*')]
data_dir.rmdir()
