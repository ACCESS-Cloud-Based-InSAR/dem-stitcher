# %%
from dem_stitcher.stitcher import download_dem 
import rasterio
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Bay Area
bounds: list = [-121.5, 34.95, -120.2, 36.25]
dem_name: str = 'glo_30'
save_raw_tiles: bool = False
force_agi_read: bool = True
out_dir: str = '.'

# %%
# Parameters
dem_name = "nasadem"
out_dir = "/Users/cmarshak/bekaert-team/dem-stitcher/tests/out"

# %% [markdown]
# # Check Download

# %%
# %%time

out_path = download_dem(bounds, 
                        dem_name, 
                        f'{out_dir}/{dem_name}_test',
                        save_raw_tiles=save_raw_tiles,
                        # More than 5 workers can cause timeout errors.
                        max_workers=5,
                        force_agi_read_for_geoid=force_agi_read)
out_path
# Out:
# Downloading nasadem tiles:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading nasadem tiles:  20%|██        | 1/5 [00:17<01:08, 17.05s/it]
# Downloading nasadem tiles:  40%|████      | 2/5 [00:31<00:46, 15.62s/it]
# Downloading nasadem tiles: 100%|██████████| 5/5 [00:31<00:00,  6.33s/it]
# CPU times: user 3.82 s, sys: 2.03 s, total: 5.85 s
# Wall time: 35 s
# PosixPath('/Users/cmarshak/bekaert-team/dem-stitcher/tests/out/nasadem_test/nasadem.dem.wgs84')

# %%
with rasterio.open(out_path) as ds:
    X_0 = ds.read(1)
    p_0 = ds.profile

# %%
fig, ax = plt.subplots()
im = ax.imshow(X_0, vmin=0)
fig.colorbar(im, label='Ellipsoidal Height (m)')

# %%
data_dir = out_path.parents[0]
[file.unlink() for file in data_dir.glob('*')]
data_dir.rmdir()
